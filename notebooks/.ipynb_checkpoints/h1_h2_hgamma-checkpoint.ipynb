# %% [markdown]
# # Library

# %%
import sys, os
import matplotlib
import scipy.io, numpy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import netCDF4
import matplotlib as mpl
mpl.rcParams['font.size'] = 12

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios

# %% [markdown]
# # 1D Size Distribution (h1, surf_area_concs * gamma_part)

# %%
directory = 'sce_completed/scenarios'
gamma_1d_dist = np.zeros((2,100,25,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            gamma_1d_dist[0,sce_index, t_index,:] = ncf.variables["gamma_size_pr"].data*1e6 # m3 to cm-3
            gamma_1d_dist[1,sce_index, t_index,:] = ncf.variables["gamma_size_comp"].data*1e6

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 74
t_index = 4
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,32)
plt.plot(diam, gamma_1d_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$h1$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 29, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 82
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.9, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 29
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.9, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 6
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,3.5)
plt.plot(diam, gamma_1d_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$h1$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 3.2, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 5
t_index = 7
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.6)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.55, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 11
t_index = 12
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.02)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.018, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 63
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,13)
plt.plot(diam, gamma_1d_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$h1$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 11.5, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 76
t_index = 19
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.04)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.035, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 78
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.5)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.45, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 92
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1.2)
plt.plot(diam, gamma_1d_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$h1$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.1, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 41
t_index = 20
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.4)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.37, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1.5)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.35, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 59
t_index = 14
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,2.5)
plt.plot(diam, gamma_1d_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$h1$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 2.35, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 60
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.4)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.37, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 91
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,9)
plt.plot(diam, gamma_1d_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, gamma_1d_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 8.3, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %% [markdown]
# # 1D Size Distribution (h2, surf_area_concs)

# %%
directory = 'sce_completed/scenarios'
surf_area_dist = np.zeros((2,100,25,180))
mass_dist = np.zeros((2,100,25,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
#             print(filename)
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            surf_area_dist[0,sce_index, t_index, :] = ncf.variables["surf_area_dist_pr"].data*1e6 # m2 to mm2
            surf_area_dist[1,sce_index, t_index, :] = ncf.variables["surf_area_dist_comp"].data*1e6
            mass_dist[0,sce_index, t_index, :] = ncf.variables["mass_dist_pr"].data*1e6 # kg to mg
            mass_dist[1,sce_index, t_index, :] = ncf.variables["mass_dist_comp"].data*1e9

# %%
plt.figure(figsize=(18,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 59
t_index = 14
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,2.1e3)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='surf_area', lw=1.5, color='#1f77b4')
plt.ylabel(r'Surface Area ($\rm \mu m^2/cm^3$)', color='#1f77b4')
plt.tick_params(axis='y', colors='#1f77b4')
plt.xlim(1e-2,1e3)
plt.ylim(0,500)
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 455, r'sce:%d T:%d h'% (sce_index, t_index))
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass', lw=1.5, color='green')
ax.set_ylim(0,100)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass (mg)', color='green')
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 82
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,2.1e3)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='surf_area', lw=1.5, color='#1f77b4')
plt.ylabel(r'Surface Area ($\rm \mu m^2/cm^3$)', color='#1f77b4')
plt.tick_params(axis='y', colors='#1f77b4')
plt.xlim(1e-2,1e3)
plt.ylim(0,100)
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 90, r'sce:%d T:%d h'% (sce_index, t_index))
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass', lw=1.5, color='green')
ax.set_ylim(0,100)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass (mg)', color='green')
plt.grid()

# Below 1:1 Line (47,18h)
plt.subplot(1,3,3)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,2.1e3)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='surf_area', lw=1.5, color='#1f77b4')
plt.ylabel(r'Surface Area ($\rm \mu m^2/cm^3$)', color='#1f77b4')
plt.tick_params(axis='y', colors='#1f77b4')
plt.xlim(1e-2,1e3)
plt.ylim(0,100)
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 90, r'sce:%d T:%d h'% (sce_index, t_index))
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass', lw=1.5, color='green')
ax.set_ylim(0,100)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass (mg)', color='green')
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(6,5))

# Above 1:1 Line (74,4h)
sce_index = 74
t_index = 4
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,2.1e3)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='surf_area', lw=1.5, color='#1f77b4')
plt.ylabel(r'Surface Area ($\rm mm^2$/$\rm mm^3$)', color='#1f77b4')
plt.tick_params(axis='y', colors='#1f77b4')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.9e3, r'sce:%d T:%d h'% (sce_index, t_index))
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass', lw=1.5, color='green')
ax.set_ylim(0,14)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass (mg)', color='green')
plt.grid()

# %%
plt.figure(figsize=(6,5))

# On 1:1 Line (82,17h)
sce_index = 82
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,100)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='surf_area')
plt.ylabel(r'Surface Area')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.8e3, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass',color='green')
# ax.set_ylim(5,200)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass', color='green')
plt.grid()

# %%
plt.figure(figsize=(6,5))

# Below 1:1 Line (47,18h)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,100)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='surf_area')
plt.ylabel(r'Surface Area')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.8e3, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
ax = plt.twinx()
p2 = ax.plot(diam, mass_dist[0, sce_index, t_index, :], label='mass',color='green')
# ax.set_ylim(5,200)
ax.tick_params(axis='y', colors='green')
ax.set_ylabel('Mass', color='green')
plt.grid()

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 6
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,500)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 450, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 5
t_index = 7
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,180)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 160, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 11
t_index = 12
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,3)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 2.5, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 63
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1.5e3)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 1.3e3, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 76
t_index = 19
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,15)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 13, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 78
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,80)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 73, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 92
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,200)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 180, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 41
t_index = 20
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,30)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 27, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,100)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 85, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 59
t_index = 14
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,500)
plt.plot(diam, surf_area_dist[0, sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1, sce_index, t_index, :], label='CA', ls='--')
plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 450, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 60
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,150)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 125, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 91
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,500)
plt.plot(diam, surf_area_dist[0,sce_index, t_index, :], label='PR')
plt.plot(diam, surf_area_dist[1,sce_index, t_index, :], label='CA', ls='--')
# plt.ylabel(r'$S_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 450, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid() 

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/h2.png')

# %% [markdown]
# # 1D Size Distribution (hgamma = h1/h2)

# %%
directory = 'sce_completed/scenarios'
gamma_1d_dist = np.zeros((2,100,25,180))
surf_area_dist = np.zeros((2,100,25,180))
hgamma = np.zeros((2,100,25,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            gamma_1d_dist[0,sce_index, t_index,:] = ncf.variables["gamma_size_pr"].data*1e6 # m3 to cm-3
            gamma_1d_dist[1,sce_index, t_index,:] = ncf.variables["gamma_size_comp"].data*1e6
            surf_area_dist[0,sce_index, t_index,:] = ncf.variables["surf_area_dist_pr"].data*1e6 # m3 to cm-3
            surf_area_dist[1,sce_index, t_index,:] = ncf.variables["surf_area_dist_comp"].data*1e6
            hgamma[0,sce_index, t_index,:] = gamma_1d_dist[0,sce_index, t_index,:]/surf_area_dist[0,sce_index, t_index,:]
            hgamma[1,sce_index, t_index,:] = gamma_1d_dist[1,sce_index, t_index,:]/surf_area_dist[1,sce_index, t_index,:]
# Out:
# <ipython-input-4-6777c835c345>:18: RuntimeWarning: invalid value encountered in true_divide
#   hgamma[0,sce_index, t_index,:] = gamma_1d_dist[0,sce_index, t_index,:]/surf_area_dist[0,sce_index, t_index,:]
# <ipython-input-4-6777c835c345>:19: RuntimeWarning: invalid value encountered in true_divide
#   hgamma[1,sce_index, t_index,:] = gamma_1d_dist[1,sce_index, t_index,:]/surf_area_dist[1,sce_index, t_index,:]

# %%
plt.figure(figsize=(18,4))

# Above 1:1 Line (59,14h)
plt.subplot(1,3,1)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,59,14,:], label='PR')
# plt.plot(diam, hgamma[1,59,14,:], label='CA')
plt.ylabel('Size-Resolved Gamma')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (59,14))
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,82, 17,:], label='PR')
# plt.plot(diam, hgamma[1,82, 17,:], label='CA')
plt.ylabel('Size-Resolved Gamma')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (82, 17))
plt.grid()

# Below 1:1 Line (47,18h)
plt.subplot(1,3,3)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,47,18,:], label='PR')
# plt.plot(diam, hgamma[1,47,18,:], label='CA')
plt.ylabel('Size-Resolved Gamma')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (47, 18))
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(6,5))

# Above 1:1 Line (74,4h)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,74, 4,:], label='PR')
plt.plot(diam, hgamma[1,74, 4,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (74, 4))
plt.legend(loc=1)
plt.grid()

# %%
plt.figure(figsize=(6,5))

# On 1:1 Line (82,17h)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,82, 17,:], label='PR')
plt.plot(diam, hgamma[1,82, 17,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (82, 17))
plt.legend(loc=0)
plt.grid()

# %%
plt.figure(figsize=(6,5))

# Below 1:1 Line (29,5h)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,29, 5,:], label='PR')
plt.plot(diam, hgamma[1,29, 5,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (29, 5))
plt.legend(loc=1)
plt.grid()

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (6,22h)
plt.subplot(1,3,1)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,6, 22,:], label='PR')
plt.plot(diam, hgamma[1,6, 22,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (6, 22))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (5,7h)
plt.subplot(1,3,2)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,5, 7,:], label='PR')
plt.plot(diam, hgamma[1,5, 7,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (5, 7))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (11,12h)
plt.subplot(1,3,3)
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,11, 12,:], label='PR')
plt.plot(diam, hgamma[1,11, 12,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (11, 12))
plt.legend(loc=1)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (6,22h)
plt.subplot(1,3,1)
sce_index = 17
t_index = 21
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (5,7h)
plt.subplot(1,3,2)
sce_index = 21
t_index = 4
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (11,12h)
plt.subplot(1,3,3)
sce_index = 42
t_index = 20
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (6,22h)
plt.subplot(1,3,1)
sce_index = 63
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (5,7h)
plt.subplot(1,3,2)
sce_index = 76
t_index = 19
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (11,12h)
plt.subplot(1,3,3)
sce_index = 78
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (6,22h)
plt.subplot(1,3,1)
sce_index = 92
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (5,7h)
plt.subplot(1,3,2)
sce_index = 41
t_index = 20
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (11,12h)
plt.subplot(1,3,3)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (6,22h)
plt.subplot(1,3,1)
sce_index = 59
t_index = 14
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (5,7h)
plt.subplot(1,3,2)
sce_index = 60
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# Below 1:1 Line (11,12h)
plt.subplot(1,3,3)
sce_index = 91
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,0.025)
plt.plot(diam, hgamma[0,sce_index, t_index,:], label='PR')
plt.plot(diam, hgamma[1,sce_index, t_index,:], label='CA')
# plt.ylabel(r'$h1/h2$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %% [markdown]
# # size-resolved wi

# %%
directory = 'sce_completed/scenarios'
mass_no3_dist = np.zeros((2,100,25,180))
mass_so4_dist = np.zeros((2,100,25,180))
wi = np.zeros((2,100,25,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            mass_no3_dist[0,sce_index, t_index,:] = ncf.variables["mass_no3_dist"].data*1e6 # m3 to cm-3
            mass_no3_dist[1,sce_index, t_index,:] = ncf.variables["mass_no3_dist_comp"].data*1e6
            mass_so4_dist[0,sce_index, t_index,:] = ncf.variables["mass_so4_dist"].data*1e6 # m3 to cm-3
            mass_so4_dist[1,sce_index, t_index,:] = ncf.variables["mass_so4_dist_comp"].data*1e6
            wi[0,sce_index, t_index,:] = mass_so4_dist[0,sce_index, t_index,:]/(mass_so4_dist[0,sce_index, t_index,:] 
                                                                                + mass_no3_dist[0,sce_index, t_index,:])
            wi[1,sce_index, t_index,:] = mass_so4_dist[1,sce_index, t_index,:]/(mass_so4_dist[1,sce_index, t_index,:] 
                                                                                + mass_no3_dist[1,sce_index, t_index,:])
# Out:
# <ipython-input-22-5c993086f3b6>:18: RuntimeWarning: invalid value encountered in true_divide
#   wi[0,sce_index, t_index,:] = mass_so4_dist[0,sce_index, t_index,:]/(mass_so4_dist[0,sce_index, t_index,:]
# <ipython-input-22-5c993086f3b6>:20: RuntimeWarning: invalid value encountered in true_divide
#   wi[1,sce_index, t_index,:] = mass_so4_dist[1,sce_index, t_index,:]/(mass_so4_dist[1,sce_index, t_index,:]

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 74
t_index = 4
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 82
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 29
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 6
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 5
t_index = 7
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.85, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 11
t_index = 12
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 63
t_index = 22
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 76
t_index = 19
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.85, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 78
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 92
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 41
t_index = 20
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 47
t_index = 18
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %%
plt.figure(figsize=(15,4))

# Above 1:1 Line (74,4h)
plt.subplot(1,3,1)
sce_index = 59
t_index = 14
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.85, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=1)
plt.grid()

# On 1:1 Line (82,17h)
plt.subplot(1,3,2)
sce_index = 60
t_index = 17
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.85, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

# Below 1:1 Line (29,5h)
plt.subplot(1,3,3)
sce_index = 91
t_index = 5
plt.xscale('log');plt.xlim(1e-2, 1e3);plt.ylim(0,1)
plt.plot(diam, wi[0,sce_index, t_index,:], label='PR')
plt.plot(diam, wi[1,sce_index, t_index,:], label='CA')
plt.ylabel(r'$w_i$')
plt.xlabel(r'$D_{\rm dry}$ ($\mu$m)')
plt.text(0.015, 0.9, r'sce:%d T:%d h'% (sce_index, t_index))
plt.legend(loc=0)
plt.grid()

plt.tight_layout()

# plt.savefig('/data/keeling/a/yicenl2/d/images/h2_hgamma/hgamma.png')

# %% [markdown]
# # Gamma_part

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0082
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0082

# %%
df_pr = pd.read_csv("gamma_part_pr.dat", sep="\s+", names=['GAMMA_PR'])
print(df_pr)

df_comp = pd.read_csv("gamma_part_comp.dat", sep="\s+", names=['GAMMA_COMP'])
print(df_comp)
""
d1 = {"gamma_pr_max": df_pr['GAMMA_PR'].max(),
      "gamma_pr_avg": df_pr['GAMMA_PR'].mean(),
      "gamma_comp_max": df_comp['GAMMA_COMP'].max(),
      "gamma_comp_avg": df_comp['GAMMA_COMP'].mean()}
df1 = pd.DataFrame(data=d1, index=[0])
print(df1)
# Out:
#         GAMMA_PR
# 0       0.018307
# 1       0.019210
# 2       0.019237
# 3       0.019200
# 4       0.008201
# ...          ...
# 970249  0.012266
# 970250  0.012297
# 970251  0.008743
# 970252  0.011084
# 970253  0.008812
#
# [970254 rows x 1 columns]
#         GAMMA_COMP
# 0         0.012521
# 1         0.011961
# 2         0.012465
# 3         0.012527
# 4         0.011813
# ...            ...
# 970249    0.008732
# 970250    0.008876
# 970251    0.009731
# 970252    0.009501
# 970253    0.006431
#
# [970254 rows x 1 columns]
#    gamma_pr_max  gamma_pr_avg  gamma_comp_max  gamma_comp_avg
# 0      0.019855      0.012985        0.019315        0.010911

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0029
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0029

# %%
df_pr = pd.read_csv("gamma_part_pr.dat", sep="\s+", names=['GAMMA_PR'])
print(df_pr)

df_comp = pd.read_csv("gamma_part_comp.dat", sep="\s+", names=['GAMMA_COMP'])
print(df_comp)
""
d1 = {"gamma_pr_max": df_pr['GAMMA_PR'].max(),
      "gamma_pr_avg": df_pr['GAMMA_PR'].mean(),
      "gamma_comp_max": df_comp['GAMMA_COMP'].max(),
      "gamma_comp_avg": df_comp['GAMMA_COMP'].mean()}
df1 = pd.DataFrame(data=d1, index=[0])
print(df1)
# Out:
#          GAMMA_PR
# 0        0.003075
# 1        0.005036
# 2        0.003954
# 3        0.002957
# 4        0.003310
# ...           ...
# 1069542  0.013188
# 1069543  0.003730
# 1069544  0.003318
# 1069545  0.003227
# 1069546  0.012739
#
# [1069547 rows x 1 columns]
#          GAMMA_COMP
# 0          0.003859
# 1          0.003759
# 2          0.003868
# 3          0.003864
# 4          0.003843
# ...             ...
# 1069542    0.003990
# 1069543    0.003988
# 1069544    0.003985
# 1069545    0.003970
# 1069546    0.003994
#
# [1069547 rows x 1 columns]
#    gamma_pr_max  gamma_pr_avg  gamma_comp_max  gamma_comp_avg
# 0      0.019998      0.008497        0.007667         0.00401

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0011
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios/sce_completed/scenarios/scenario_0011

# %%
df_pr = pd.read_csv("gamma_part_pr.dat", sep="\s+", names=['GAMMA_PR'])
print(df_pr)

df_comp = pd.read_csv("gamma_part_comp.dat", sep="\s+", names=['GAMMA_COMP'])
print(df_comp)
""
d1 = {"gamma_pr_max": df_pr['GAMMA_PR'].max(),
      "gamma_pr_avg": df_pr['GAMMA_PR'].mean(),
      "gamma_comp_max": df_comp['GAMMA_COMP'].max(),
      "gamma_comp_avg": df_comp['GAMMA_COMP'].mean()}
df1 = pd.DataFrame(data=d1, index=[0])
print(df1)
# Out:
#         GAMMA_PR
# 0       0.006722
# 1       0.014839
# 2       0.005609
# 3       0.005521
# 4       0.014777
# ...          ...
# 197859  0.019706
# 197860  0.019564
# 197861  0.019982
# 197862  0.019742
# 197863  0.019697
#
# [197864 rows x 1 columns]
#         GAMMA_COMP
# 0         0.007304
# 1         0.007338
# 2         0.007315
# 3         0.007281
# 4         0.007351
# ...            ...
# 197859    0.019823
# 197860    0.019535
# 197861    0.012895
# 197862    0.019811
# 197863    0.019688
#
# [197864 rows x 1 columns]
#    gamma_pr_max  gamma_pr_avg  gamma_comp_max  gamma_comp_avg
# 0      0.019991      0.015155        0.019957        0.013585

# %% [markdown]
# # 2d_gamma_dist

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios

# %%
directory = 'sce_completed/scenarios'
gamma_dist = np.zeros((2,100,25,50,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
            diam_edges = ncf.variables["diam_edges"].data *1e6
            gamma_edges = ncf.variables["gamma_edges"].data
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            gamma_dist[0,sce_index, t_index, :, :] = ncf.variables["diam_gamma_dist_pr"].data
            gamma_dist[1,sce_index, t_index, :, :] = ncf.variables["diam_gamma_dist_avg"].data
# Out:
# /data/keeling/a/yicenl2/miniconda3/lib/python3.8/site-packages/scipy/io/netcdf.py:308: RuntimeWarning: Cannot close a netcdf_file opened with mmap=True, when netcdf_variables or arrays referring to its data still exist. All data arrays obtained from such files refer directly to data on disk, and must be copied before the file can be cleanly closed. (See netcdf_file docstring for more information on mmap.)
#   warnings.warn((

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(15,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_dist[1, 74, 4,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (74, 4))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_dist[1, 82, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (82, 17))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_dist[1, 29, 5,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (29, 5))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_dist[1, 92, 18,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (92, 18))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_dist[1, 41, 20,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (41, 20))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_dist[1, 47, 18,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (47, 18))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_dist[1, 6, 22,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (6, 22))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_dist[1, 5, 7,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (5, 7))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_dist[1, 11, 12,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (11, 12))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_dist[1, 63, 22,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (63, 22))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_dist[1, 76, 19,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (76, 19))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_dist[1, 78, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (78, 17))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_dist[1, 59, 14,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (59, 14))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_dist[1, 60, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (60, 17))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_dist[1, 91, 5,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (91, 5))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %% [markdown]
# # 2d_gamma_surf_dist

# %%
cd /data/keeling/a/yicenl2/c/git/project/partmc/scenarios
# Out:
# /data/nriemer/c/yicenl2/git/project/partmc/scenarios

# %%
directory = 'sce_completed/scenarios'
gamma_surf_dist = np.zeros((2,100,25,50,180))

for subdir, dirs, files in os.walk(directory):
    for file in files:
        filename = subdir + os.sep + file
        if ('out/urban_plume_00000' in filename and '.nc' in filename):
            diam_edges = ncf.variables["diam_edges"].data *1e6
            gamma_edges = ncf.variables["gamma_edges"].data
            t_index = int(filename[-13:-11]) - 1
            sce_index = int(filename[-38:-36])
            ncf = scipy.io.netcdf_file(filename)
            diam = ncf.variables["diam"].data* 1e6 # m to µm
            gamma_surf_dist[0,sce_index, t_index, :, :] = ncf.variables["diam_gamma_surf_dist_pr"].data
            gamma_surf_dist[1,sce_index, t_index, :, :] = ncf.variables["diam_gamma_surf_dist_avg"].data

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(15,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 74, 4,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,1e3)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (74, 4))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 82, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e10)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (82, 17))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 29, 5,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e5), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (29, 5))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 92, 18,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,30)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (92, 18))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 41, 20,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (41, 20))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 47, 18,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (47, 18))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 6, 22,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (6, 22))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 5, 7,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (5, 7))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 11, 12,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (11, 12))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 63, 22,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (63, 22))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 76, 19,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (76, 19))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 78, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (78, 17))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')

# %%
# print(gamma_dist[0, 29, 5,:,:])

plt.figure(figsize=(18,4))
X, Y = np.meshgrid(diam_edges, gamma_edges)

plt.subplot(1,3,1)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 59, 14,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (59, 14))
plt.grid(True)
#*************
plt.subplot(1,3,2)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 60, 17,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (60, 17))
plt.grid(True)
#*************
plt.subplot(1,3,3)
p = plt.pcolormesh (X, Y, gamma_surf_dist[1, 91, 5,:,:], 
                    norm = mpl.colors.LogNorm(vmin=1e0, vmax=1e2), linewidths = 0.1)
plt.xlim(1e-2,1e3)
plt.xscale('log')

plt.ylim(0,0.025)
# plt.ylabel('gamma_dist_avg')
plt.yscale('linear')
plt.text(0.015, 0.022, r'sce:%d T:%d h'% (91, 5))
plt.grid(True)
# plt.savefig('/data/keeling/a/yicenl2/d/images/' + s[i] + '_On.png')
